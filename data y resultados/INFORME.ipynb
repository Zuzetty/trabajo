# %% [markdown]
# <h1 align = "center">Universidad de Piura- Vida Universitaria</h1>
#
# <p align = "center"><img src= "https://www.udep.edu.pe/admision-piura/wp-content/uploads/sites/75/2021/03/favicon-udep.jpg"</p>
#
#
#
#
# <h2>Integrantes</h2>
# <ul type="none">
# <li>Aaron Josue Atarama Chanduvi</li>
# <li>Omar Atarama Chanduvi</li>
# <li>Marlon Camba Calle</li>
# </ul>

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Introducción
# <p align = "justify">En la actualidad el uso de lenguajes de programación está siendo muy utilizado y se ha logrado desarrollar con mayor naturalidad a partir del 2013, pues según Challenger et all (2014), la Industria Informática gracias al software libre, el cual se plantea como un código de libre acceso para su uso, ejecución, distribución y modificación, podría utilizarse para cualquier fin y modificarse de ser necesario. </p>
# <p align = "justify"> Debido a ello. Algunas instituciones en lo últimos años han tratado de incorporar estas Tecnologías de Información y Comunicación (TIC), con el fin que el alumnado se desenvuelva en la sociedad actual, sin embargo, aunque se tiene la voluntad de lograr esto en el alumnado, en ocasiones a los docentes les suele costar desarrollar estas tecnologías, debido a que se tiene menor dominio que los estudiantes. (Almirón y Porro, 2014).</p>
#
# <p align = "justify"> Es por ello que nosotros hemos creído conveniente analizar los lenguajes de programación como herramientas básicas para la construcción de programas, y la implementación a través del tiempo con la finalidad de establecer que tanto se ha desarrollado los lenguajes, y así brindarnos un proxi de avance tecnológico en el tiempo.</p>
# <p align = "justify"> Y con este análisis realizado tratar de responder algunas interrogantes que se presentan:</p>

# %% [markdown]
# *   •	¿Es significativo afirmar que a medida que transcurre el tiempo existe mayor desarrollo de lenguajes de programación tecnológica?
# *   •	¿Qué factores influyen en el progreso de los lenguajes de programación?
# *   •	¿el tiempo por sí mismo es suficiente a la hora de explicar el incremento de los lenguajes de programación?

# %% [markdown]
# <p align = "justify"> La estructura que a continuación se presenta consta de un análisis del problema que lo establecemos en la sección II, en la sección III analizamos los datos, y finalmente en la sección IV tenemos las conclusiones.</p>

# %% [markdown]
# # Análisis del Problema:
# <p align = "justify">La razón para analizar la cantidad de lenguajes de programación (grafico 1) a través de su periodo de tiempo es tratar de ver en qué periodos han tenido un mayor incremento y como va su comportamiento actualmente. </p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico1.png")

# %% [markdown]
# <p align = "justify">Primeramente, recabamos la data de Kaggle, en la cual encontramos de las variables como repositorios (archivos de programación), la edición y los pull request (son las peticiones para editar), esta data es encontrada entre los años 2012 y 2021.</p>
# <p align = "justify"> Una razón muy importante para analizar el comportamiento de los lenguajes de programación a lo largo del tiempo es que a pesar que existía una tendencia creciente desde el 2012, últimamente preocupa el hecho que las ediciones en lenguajes de programación han venido descendiendo de forma abrupta a partir del 2017 aproximadamente, como se muestra en el grafico 2.</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico2.png")

# %% [markdown]
# <p align = "justify">Esta tendencia que se muestra en el anterior gráfico, es muy compartida con los distintos lenguajes de programación que existen como es el caso de JavaScript, Python, PHP, Java y c++, como los principales lenguajes de programación y ello se evidencia en el grafico 3.</p>

# %% [markdown]
# <p></p>
# <p></p>
# <p></p>
# <p></p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico3.png")

# %% [markdown]
# <p align = "justify">Para el caso de los Pull request o mejor conocidos como peticiones para editar, también comparte la tendencia de los dos anteriores gráficos, aunque se reduce en cierta medida (gráfico 4). </p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico4.png")

# %% [markdown]
# <p align = "justify">Si bien es cierto que este descenso se debe a algún motivo en particular no hemos encontrado una data completa para demostrar la razón fundamental de dicho descenso.</p>

# %% [markdown]
# # Análisis de datos.
# <p align = "justify">Para entender lo que se paletea en la problemática se ha realizado una regresión tomando los 5 programas principales en el cual tenemos como variable dependiente la cantidad de repositorios del lenguaje de programación que existen y esto lo explicamos a través del tiempo.</p>
# <p align = "justify">Los resultados que obtenemos al realizar el método de mínimos cuadrados ordinarios nos indican una variable year el cual está relacionada positivamente con el incremento de repositorios de lenguaje de programación en Python, y a la hora de explicar el modelo es significativo como se puede observar en el intervalo de confianza el cual alberga el t-estadístico lo cual es un indicio que es significativo.</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/tabla1.png")

# %% [markdown]
# <p>Gráficamente la relación entre año y repositorios de lenguaje de programación de Python se daría como el grafico 5.</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico6.png")

# %% [markdown]
# <p align = "justify">Para el caso de JavaScript, aunque está relacionado positivamente con el año en este caso el año no explica la relación positiva que establecen estas dos variables.</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/tabla2.png")

# %% [markdown]
# <p>Gráficamente la relación entre año y repositorios de lenguaje de programación de JavaScript se daría como el grafico 6. </p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico7.png")

# %% [markdown]
# # Concluciones.
# <p align = "justify">Como hemos visto existe una relación positiva entre los repositorios de lenguaje de programación y los años, esto no quiere decir que es suficiente para explicar el comportamiento de los repositorios de lenguajes de programación, pues para realizar un análisis completo tenemos primeramente contar con más variables en la data con las que se pueda controlar esta variable dependiente.</p>
# <p align = "justify">Y así, se pueda obtener un valor real de la influencia del pasar de los años en los repositorios de lenguajes de programación y también poder explicar algunas preguntas como las que se plantearon en la introducción, como una influencia de la educación en lenguajes de programación sobre la cantidad de repositorios de lenguajes de programación.</p>
