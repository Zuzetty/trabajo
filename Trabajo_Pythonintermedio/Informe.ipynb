# %% [markdown]
# <h1 align = "center">Universidad de Piura- Vida Universitaria</h1>
#
# <p align = "center"><img src= "https://www.udep.edu.pe/admision-piura/wp-content/uploads/sites/75/2021/03/favicon-udep.jpg"</p>
#
#
#
#
# <h2>Integrantes</h2>
# <ul type="none">
# <li>Marlon Camba Calle</li>
# </ul>

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Introducción
# <p align = "justify">El estudio del rendimiento académico no ha podido estudiarse de un modo directo,sino más bien se estudia su relación con variables que influyen directa o indirectamente con el rendimiento que se refleja en el sistema de calificación de los alumnos. </p>
# <p align = "justify"> Es debido a ello que Jiménez (2000) define el rendimiento escolar como un nivel de conocimientos logrado en un área o materia comparado con la norma de edad y nivel académico, lo cual nos ubica únicamente en la calificación final del alumno comparándola
# con una media estadísticamente hablando y ello se debe a que es la forma mas rapida de medir el rendimiento.</p>
#
# <p align = "justify"> Es por ello que el presente estudio pretende abordar el tiempo de estudio como factor que define e
# influye en la calidad de la educación, entendiendo la misma como el éxito respecto a los resultados académicos. Siendo conscientes de que los resultados académicos representan una variable de carácter multifactorial, donde intervienen mas factores, pero en este estudio centraremos nuestra atención en el tiempo de estudio como elemento
# vertebrador de los procesos de enseñanza y aprendizaje</p>
# <p align = "justify"> Y con este análisis realizado tratar de responder algunas interrogantes que se presentan:</p>

# %% [markdown]
# *   •	¿Qué tanto influye las hoas de estudio en la obtencion de notas?
# *   •	¿el programa realmente generaliza el objetivo?

# %% [markdown]
# <p align = "justify"> La estructura que a continuación se presenta consta de un análisis del problema que lo establecemos en la sección II, en la sección III analizamos los datos, y finalmente en la sección IV tenemos las conclusiones.</p>

# %% [markdown]
# # Análisis del Problema:
# <p align = "justify">Primeramente, la data fue recabada de de Kaggle, en la cual encontramos una data en la que se nos ofrece las horas de estudio y las notas, acorde a ello se pretende analizar la data y establecer un programa en el que se estime las horas de estudio para lograr la nota deseada.</p>
# <p align = "justify"> En la data se nos presentan estadisticas muy interesantes los promedios de notas y tiempo de estudio, ademas se tiene el valor maximo y el minimo que se puede alcanzar en las notas.</p>
# <p align = "justify"> </p> Ademas tenemos una dispercion de datos representadas por std la cul mide que tan dispersos son los datos respecto a la media, en este caso la variable mas dispersa es la de las notas (Marks).</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/estadisticas.png")

# %% [markdown]
# <p align = "justify">Graficamente tenemos una grafica de dispersion de datos en la cual se nos presenta la relacion de las 2 variables horas de estudio y notas, en este grafico podemos notar una clara tendencia la cual es que a mayor horas de estudio, mayor sera la nota obtenida.  </p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/grafico de dispersion.png")

# %% [markdown]
# <p align = "justify">Esta tendencia que se muestra en el anterior gráfico, es muy compartida con los distintos lenguajes de programación que existen como es el caso de JavaScript, Python, PHP, Java y c++, como los principales lenguajes de programación y ello se evidencia en el grafico 3.</p>

# %% [markdown]
# <p></p>
# <p></p>
# <p></p>
# <p></p>

# %% [markdown]
# # Análisis de datos.
# <p align = "justify">Para entender lo que se paletea en la problemática heos elaborado un programa que determina una tendencia en la cual se puede observar una correlacion positiva entre las notas y las horas de estudio.</p>
# <p align = "justify">Ahora analizamos el entrenamiento del modelo y encontramos un modelo generalizado, lo cual se puede evidenciar en la imagen siguiente en la cual tenemos el R-cuadrado de trai, y el R-cuadrado de validacion son similaes y estan por encima del 50%.</p>

# %%
#@title
from IPython.display import Image
Image ("/content/drive/MyDrive/Trabajo/R2.png")

# %% [markdown]
# # Concluciones.
# <p align = "justify">Como hemos visto existe una relación positiva entre las notas y las horas de estudio, esto no quiere decir que es suficiente para explicar el comportamiento del rendimiento academico representado por las notas a obtener, pues para realizar un análisis completo tenemos primeramente contar con más variables en la data con las que se pueda controlar esta variable dependiente.</p>
# <p align = "justify">Y así, se pueda obtener un valor real de la influencia de las horas de estudio en la obtencion de la nota y también poder explicar algunas preguntas como las que se plantearon en la introducción.</p>
# <p align = "justify">Finalmente tenemos un programa que nos predice las horas de estudio que nesecitas para cumplir con el objetivo de l nota que deseas obtener.</p>
